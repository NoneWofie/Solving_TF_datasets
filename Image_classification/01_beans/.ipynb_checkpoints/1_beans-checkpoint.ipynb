# %% [markdown]
# # Beans Dataset
#
# Contains images of beans taken in the bield using smartphone cameras.
#
# Consist of 3 classes:
# * 2 Disease class (Angular Leaf Spot and Bean Rust)
# * 1 Healty class
#
# https://www.tensorflow.org/datasets/catalog/beans

# %%
#Import libraries
import tensorflow as tf
from tensorflow.keras import layers

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import zipfile

tf.__version__
# Out:
# '2.10.0'

# %% [markdown]
# ## Downloading Beans Dataset
#
# https://github.com/AI-Lab-Makerere/ibean/

# %%
# !curl https://storage.googleapis.com/ibeans/train.zip -o train.zip
# !curl https://storage.googleapis.com/ibeans/validation.zip -o valid.zip
# !curl https://storage.googleapis.com/ibeans/test.zip -o test.zip

# %%
for each_sets in ["train.zip", "valid.zip", "test.zip"]:
    zip_ref = zipfile.ZipFile(each_sets, "r")
    zip_ref.extractall("./datasets/")

# %% [markdown]
# ## Exploring Directories

# %%
import os

for dirpath, dirnames, filenames in os.walk("datasets"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 3 directories and 0 images in 'datasets'.
# There are 3 directories and 0 images in 'datasets\test'.
# There are 0 directories and 43 images in 'datasets\test\angular_leaf_spot'.
# There are 0 directories and 43 images in 'datasets\test\bean_rust'.
# There are 0 directories and 42 images in 'datasets\test\healthy'.
# There are 3 directories and 0 images in 'datasets\train'.
# There are 0 directories and 345 images in 'datasets\train\angular_leaf_spot'.
# There are 0 directories and 348 images in 'datasets\train\bean_rust'.
# There are 0 directories and 342 images in 'datasets\train\healthy'.
# There are 3 directories and 0 images in 'datasets\validation'.
# There are 0 directories and 44 images in 'datasets\validation\angular_leaf_spot'.
# There are 0 directories and 45 images in 'datasets\validation\bean_rust'.
# There are 0 directories and 44 images in 'datasets\validation\healthy'.

# %% [markdown]
# ## Getting class names from directory

# %%
import pathlib

data_dir = pathlib.Path("./datasets/train/") # turn our training path into a Python path
class_names = np.array(sorted([item.name for item in data_dir.glob('*')])) # created a list of class_names from the subdirectories

print(class_names)
# Out:
# ['angular_leaf_spot' 'bean_rust' 'healthy']

# %% [markdown]
# ## Viewing random Images

# %%
import helper_functions

# %%
# View a random image from the training dataset
img = helper_functions.view_random_image(target_dir="./datasets/train/",
                        target_class="healthy")

# %%
# View a random image from the training dataset
img = helper_functions.view_random_image(target_dir="./datasets/train/",
                        target_class="bean_rust")

# %%
# View a random image from the training dataset
img = helper_functions.view_random_image(target_dir="./datasets/train/",
                        target_class="angular_leaf_spot")

# %%
from helper_functions import view_random_image_per_class

# %%
view_random_image_per_class(classes=class_names)

# %% [markdown]
# ## Importing Images using ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255.,
                                  horizontal_flip=True,
                                  zoom_range=0.3,
                                  rotation_range=0.3,
                                  shear_range=0.3
                                  )

valid_datagen = ImageDataGenerator(rescale=1/255.)

test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
TRAIN_PATH = "./datasets/train/"
train_dataset = train_datagen.flow_from_directory(TRAIN_PATH)

VALID_PATH = "./datasets/validation/"
valid_dataset = valid_datagen.flow_from_directory(VALID_PATH)

TEST_PATH = "./datasets/test/"
test_dataset = test_datagen.flow_from_directory(TEST_PATH)

train_dataset, valid_dataset, test_dataset
# Out:
# Found 1034 images belonging to 3 classes.
# Found 133 images belonging to 3 classes.
# Found 128 images belonging to 3 classes.
# (<keras.preprocessing.image.DirectoryIterator at 0x1e00bdc4d00>,
#  <keras.preprocessing.image.DirectoryIterator at 0x1e0089edc70>,
#  <keras.preprocessing.image.DirectoryIterator at 0x1e00d1728b0>)

# %%
# example_image, example_labels = next(train_dataset)
# # example_image, example_labels

# %%
# fig, axs = plt.subplots(3, 6, figsize=(20, 10))

# for each_row in axs:
#     for index, each_column in enumerate(each_row):
#         each_column.imshow(example_image[index])
#         each_column.set_title(class_names[example_labels[index].argmax()])
#         each_column.axis(False)
        
# plt.tight_layout()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=[256, 256, 3], name="input_layer"),
    tf.keras.layers.Conv2D(filters=32, activation="relu", kernel_size=3),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(len(class_names), activation="softmax")
])

model.compile(loss=tf.keras.losses.categorical_crossentropy,
             optimizer="adam",
             metrics=["accuracy"])

model.fit(train_dataset, epochs=100, validation_data=valid_dataset, 
          steps_per_epoch=int( len(train_dataset) * 0.3), 
          validation_steps=len(valid_dataset),
                              callbacks=[tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 9/9 [==============================] - 8s 634ms/step - loss: 29.6339 - accuracy: 0.3924 - val_loss: 25.8577 - val_accuracy: 0.3308
# Epoch 2/100
# 9/9 [==============================] - 5s 549ms/step - loss: 12.9041 - accuracy: 0.2951 - val_loss: 3.9627 - val_accuracy: 0.5188
# Epoch 3/100
# 9/9 [==============================] - 4s 523ms/step - loss: 2.3085 - accuracy: 0.4624 - val_loss: 1.4961 - val_accuracy: 0.5489
# Epoch 4/100
# 9/9 [==============================] - 4s 491ms/step - loss: 1.2847 - accuracy: 0.5376 - val_loss: 1.1878 - val_accuracy: 0.5714
# Epoch 5/100
# 9/9 [==============================] - 4s 480ms/step - loss: 1.0079 - accuracy: 0.5752 - val_loss: 1.0632 - val_accuracy: 0.6165
# Epoch 6/100
# 9/9 [==============================] - 4s 454ms/step - loss: 0.8855 - accuracy: 0.6165 - val_loss: 1.4062 - val_accuracy: 0.5714
# Epoch 7/100
# 9/9 [==============================] - 4s 465ms/step - loss: 0.8768 - accuracy: 0.6241 - val_loss: 0.9952 - val_accuracy: 0.6090
# Epoch 8/100
# 9/9 [==============================] - 4s 500ms/step - loss: 0.8050 - accuracy: 0.6875 - val_loss: 1.3040 - val_accuracy: 0.6090
# Epoch 9/100
# 9/9 [==============================] - 4s 486ms/step - loss: 0.7772 - accuracy: 0.6875 - val_loss: 0.9193 - val_accuracy: 0.6767
# Epoch 10/100
# 9/9 [==============================] - 5s 505ms/step - loss: 0.7808 - accuracy: 0.6979 - val_loss: 0.8406 - val_accuracy: 0.7068
# Epoch 11/100
# 9/9 [==============================] - 4s 479ms/step - loss: 0.7423 - accuracy: 0.6597 - val_loss: 0.7972 - val_accuracy: 0.7669
# Epoch 12/100
# 9/9 [==============================] - 4s 471ms/step - loss: 0.6294 - accuracy: 0.7331 - val_loss: 0.9593 - val_accuracy: 0.7293
# Epoch 13/100
# 9/9 [==============================] - 4s 432ms/step - loss: 0.5694 - accuracy: 0.7556 - val_loss: 0.8291 - val_accuracy: 0.7669
# Epoch 14/100
# 9/9 [==============================] - 4s 491ms/step - loss: 0.6294 - accuracy: 0.7361 - val_loss: 0.8156 - val_accuracy: 0.6617
# Epoch 15/100
# 9/9 [==============================] - 4s 485ms/step - loss: 0.6521 - accuracy: 0.7222 - val_loss: 0.8707 - val_accuracy: 0.7519
# Epoch 16/100
# 9/9 [==============================] - 5s 506ms/step - loss: 0.5879 - accuracy: 0.7569 - val_loss: 0.7685 - val_accuracy: 0.7669
# Epoch 17/100
# 9/9 [==============================] - 4s 480ms/step - loss: 0.5951 - accuracy: 0.7361 - val_loss: 0.9598 - val_accuracy: 0.7068
# Epoch 18/100
# 9/9 [==============================] - 4s 463ms/step - loss: 0.6134 - accuracy: 0.7481 - val_loss: 0.7046 - val_accuracy: 0.7218
# Epoch 19/100
# 9/9 [==============================] - 4s 480ms/step - loss: 0.5968 - accuracy: 0.7535 - val_loss: 0.6638 - val_accuracy: 0.7444
# Epoch 20/100
# 9/9 [==============================] - 4s 466ms/step - loss: 0.5687 - accuracy: 0.7707 - val_loss: 0.7446 - val_accuracy: 0.7519
# Epoch 21/100
# 9/9 [==============================] - 4s 439ms/step - loss: 0.6274 - accuracy: 0.7707 - val_loss: 0.6217 - val_accuracy: 0.7744
# Epoch 22/100
# 9/9 [==============================] - 4s 458ms/step - loss: 0.6067 - accuracy: 0.7368 - val_loss: 0.7296 - val_accuracy: 0.7143
# Epoch 23/100
# 9/9 [==============================] - 4s 483ms/step - loss: 0.5983 - accuracy: 0.7569 - val_loss: 0.6696 - val_accuracy: 0.7519
# Epoch 24/100
# 9/9 [==============================] - 5s 513ms/step - loss: 0.5631 - accuracy: 0.7674 - val_loss: 0.6691 - val_accuracy: 0.7444
# Epoch 25/100
# 9/9 [==============================] - 4s 484ms/step - loss: 0.4873 - accuracy: 0.8021 - val_loss: 0.7001 - val_accuracy: 0.7744
# Epoch 26/100
# 9/9 [==============================] - 4s 495ms/step - loss: 0.5169 - accuracy: 0.7951 - val_loss: 0.6997 - val_accuracy: 0.6992

# %%
model.evaluate(test_dataset)
# Out:
# 4/4 [==============================] - 1s 184ms/step - loss: 0.6273 - accuracy: 0.7734
# [0.6272731423377991, 0.7734375]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=[256, 256, 3], name="input_layer"),
    tf.keras.layers.Conv2D(filters=32, activation="relu", kernel_size=3),
    tf.keras.layers.Conv2D(filters=32, activation="relu", kernel_size=3),
    tf.keras.layers.Conv2D(filters=32, activation="relu", kernel_size=3),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(len(class_names), activation="softmax")
])

model.compile(loss=tf.keras.losses.categorical_crossentropy,
             optimizer="adam",
             metrics=["accuracy"])

model.fit(train_dataset, epochs=100, validation_data=valid_dataset, 
          steps_per_epoch=int( len(train_dataset) * 0.3), 
          validation_steps=len(valid_dataset),
                              callbacks=[tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)])
